# %%
# PART A

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://github.com/TanayDajgude/Data_Sets/raw/main/studentacademicperf.csv')

# %%
df
# Out:
#     gender  math score  reading score  writing score  placement score  \
# 0   female        66.0           94.0           68.0             94.0
# 1     male        74.0           89.0           75.0             80.0
# 2     male        68.0           92.0           73.0             93.0
# 3   female        70.0           98.0           77.0             93.0
# 4     male        75.0           93.0           61.0             97.0
# 5   female        64.0           86.0           61.0             88.0
# 6   female        90.0           80.0           78.0             82.0
# 7   female        76.0           91.0           79.0             89.0
# 8     male        73.0           97.0           98.0             98.0
# 9     male        79.0           88.0           61.0             92.0
# 10  female        75.0           83.0           80.0             92.0
# 11    male        68.0           88.0           66.0             92.0
# ...

# %%
df.isnull().sum()
# Out:
# gender                   0
# math score               2
# reading score            1
# writing score            1
# placement score          1
# club join year           0
# placement offer count    0
# region                   4
# dtype: int64

# %%
m_v = df['math score'].mean()

# %%
df['math score'].fillna(value = m_v, inplace=True)

# %%
df
# Out:
#     gender  math score  reading score  writing score  placement score  \
# 0   female        66.0           94.0           68.0             94.0
# 1     male        74.0           89.0           75.0             80.0
# 2     male        68.0           92.0           73.0             93.0
# 3   female        70.0           98.0           77.0             93.0
# 4     male        75.0           93.0           61.0             97.0
# 5   female        64.0           86.0           61.0             88.0
# 6   female        90.0           80.0           78.0             82.0
# 7   female        76.0           91.0           79.0             89.0
# 8     male        73.0           97.0           98.0             98.0
# 9     male        79.0           88.0           61.0             92.0
# 10  female        75.0           83.0           80.0             92.0
# 11    male        68.0           88.0           66.0             92.0
# ...

# %%
med = df['reading score'].median()

# %%
df['reading score'].fillna(value = med, inplace = True)

# %%
df
# Out:
#     gender  math score  reading score  writing score  placement score  \
# 0   female        66.0           94.0           68.0             94.0
# 1     male        74.0           89.0           75.0             80.0
# 2     male        68.0           92.0           73.0             93.0
# 3   female        70.0           98.0           77.0             93.0
# 4     male        75.0           93.0           61.0             97.0
# 5   female        64.0           86.0           61.0             88.0
# 6   female        90.0           80.0           78.0             82.0
# 7   female        76.0           91.0           79.0             89.0
# 8     male        73.0           97.0           98.0             98.0
# 9     male        79.0           88.0           61.0             92.0
# 10  female        75.0           83.0           80.0             92.0
# 11    male        68.0           88.0           66.0             92.0
# ...

# %%
m_v = df['writing score'].mean()

# %%
df['writing score'].fillna(value = m_v, inplace = True)

# %%
df
# Out:
#     gender  math score  reading score  writing score  placement score  \
# 0   female        66.0           94.0      68.000000             94.0
# 1     male        74.0           89.0      75.000000             80.0
# 2     male        68.0           92.0      73.000000             93.0
# 3   female        70.0           98.0      77.000000             93.0
# 4     male        75.0           93.0      61.000000             97.0
# 5   female        64.0           86.0      61.000000             88.0
# 6   female        90.0           80.0      78.000000             82.0
# 7   female        76.0           91.0      79.000000             89.0
# 8     male        73.0           97.0      98.000000             98.0
# 9     male        79.0           88.0      61.000000             92.0
# 10  female        75.0           83.0      80.000000             92.0
# 11    male        68.0           88.0      66.000000             92.0
# ...

# %%
med = df['placement score'].median()

# %%
df['placement score'].fillna(value = med, inplace = True)

# %%
df
# Out:
#     gender  math score  reading score  writing score  placement score  \
# 0   female        66.0           94.0      68.000000             94.0
# 1     male        74.0           89.0      75.000000             80.0
# 2     male        68.0           92.0      73.000000             93.0
# 3   female        70.0           98.0      77.000000             93.0
# 4     male        75.0           93.0      61.000000             97.0
# 5   female        64.0           86.0      61.000000             88.0
# 6   female        90.0           80.0      78.000000             82.0
# 7   female        76.0           91.0      79.000000             89.0
# 8     male        73.0           97.0      98.000000             98.0
# 9     male        79.0           88.0      61.000000             92.0
# 10  female        75.0           83.0      80.000000             92.0
# 11    male        68.0           88.0      66.000000             92.0
# ...

# %%
df.replace(to_replace = np.nan, value='pune', inplace = True)

# %%
df.isnull().sum()
# Out:
# gender                   0
# math score               0
# reading score            0
# writing score            0
# placement score          0
# club join year           0
# placement offer count    0
# region                   0
# dtype: int64

# %%
# PART B

# %%
df1 = pd.read_csv('https://github.com/TanayDajgude/Data_Sets/raw/main/demo1.csv')

# %%
col = ['math score', 'reading score', 'writing score', 'placement score']

# %%
df1.boxplot(col)
# Out:
# <Axes: >

# %%
print(np.where(df['math score']>90))
# Out:
# (array([], dtype=int64),)

# %%
print(np.where(df['reading score']<30))
# Out:
# (array([], dtype=int64),)

# %%
print(np.where(df['writing score']<25))
# Out:
# (array([20]),)

# %%
# Detecting outliers using Z score

# %%
from scipy import stats

# %%
z = np.abs(stats.zscore(df1['math score']))

# %%
print(z)
# Out:
# 0     0.175646
# 1     0.528288
# 2     0.214828
# 3     0.920112
# 4     0.254010
# 5     0.449923
# 6     0.293193
# 7     0.410740
# 8     0.332375
# 9     0.371558
# 10    2.958952
# 11    0.214828
# 12    0.175646
# 13    0.254010
# 14    0.371558
# 15    0.254010
# 16    0.059449
# 17    0.175646
# 18    0.371558
# 19    0.097281
# 20    0.606653
# 21    0.608004
# 22    0.489105
# 23    0.410740
# 24    0.371558
# 25    3.742601
# 26    0.489105
# 27    0.528288
# 28    1.391653
# Name: math score, dtype: float64

# %%
threshold = 0.18

# %%
sample_outliers = np.where(z < threshold)
sample_outliers
# Out:
# (array([ 0, 12, 16, 17, 19]),)

# %%
# Detecting outliers using Inter Quartile range

# %%
ndf = df1

# %%
sorted_rscore = sorted(ndf['reading score'])

# %%
sorted_rscore
# Out:
# [1,
#  16,
#  45,
#  60,
#  60,
#  61,
#  62,
#  62,
#  62,
#  65,
#  65,
#  65,
#  67,
#  67,
#  68,
#  68,
#  69,
#  70,
#  71,
#  72,
#  73,
#  74,
#  77,
#  77,
#  77,
#  78,
#  79,
#  80,
#  120]

# %%
q1 = np.percentile(sorted_rscore, 25)
q3 = np.percentile(sorted_rscore, 75)

# %%
q1, q3
# Out:
# (62.0, 74.0)

# %%
IQR = q3-q1

# %%
lower_bound = q1-(1.5*IQR)
upper_bound = q3+(1.2*IQR)
print(lower_bound,upper_bound)
# Out:
# 44.0 88.4

# %%
r_outlier = []
for i in sorted_rscore:
  if(i < lower_bound or i > upper_bound ):
    r_outlier.append(i)
print(r_outlier)
# Out:
# [1, 16, 120]
